# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests
import plotly as ply

np.random.seed(613)

# %% [markdown]
# # seaborn a data visualization package, similar to matplotlib, but takes care of some semantic mapping for us.
# ‘tips’ sample dataset, which is available as part of the
# seaborn (sns) package
#     - This dataset include total_bill, tip, sex smoker, day, time, size.
#     - [244 rows x 7 columns]
#
# import numpy as np
# import matplotlib.pyplot as plt
# import pandas as pd
# import scipy
# import plotly as ply

# %%
tips = sns.load_dataset('tips')
print (tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.lineplot(data=tips,
             x= 'total_bill',
             y= 'tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.set_style('dark')

sns.lineplot(data=tips,
             x= 'total_bill',
             y= 'tip')
# you can use another set styles like whitegrid, darkgrid (with lines)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.set_style('darkgrid')



tipgraph = sns.lineplot(data=tips,
             x= 'total_bill',
             y= 'tip')
tipgraph.set(title='Tips vs. Total Bill',
             xlabel = 'Total Bill ($)',
            ylabel = 'Tip Amount ($)')
# Out:
# [Text(0.5, 1.0, 'Tips vs. Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip Amount ($)')]

# %%
fig = plt.subplots(figsize=(10, 3))

tipgraph = sns.lineplot(data=tips,
                    x='total_bill',
                    y='tip',
                    color = 'hotpink',
                    linestyle = '--',
                     linewidth = 3,
                     marker = 'o',
                    markerfacecolor = 'indigo')

tipgraph.set(title = 'Tips vs. Total Bill',
             xlabel = 'Total Bill ($)',
             ylabel = 'Tip Amount ($)')
# Out:
# [Text(0.5, 1.0, 'Tips vs. Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip Amount ($)')]

# %%
tipgraph = sns.scatterplot(data=tips, x='total_bill',
                        y='tip', 
                        style = 'time', 
                        hue = 'day', 
                        palette = ['purple',
                        'hotpink', 'deepskyblue',
                        'yellowgreen'])

tipgraph.set(title='Tips vs. Total Bill',
            xlabel='Total Bill ($)',
            ylabel='Tip Amount ($)')
plt.show()

# %% [markdown]
# # PAirplot
# To compare variables
# To explore relationships

# %%
sns.pairplot(
    data = tips,
    hue = 'day')

# %% [markdown]
# # Relplot
# Let us explore specific levels within variables

# %%
daysplot = sns.relplot(
    data=tips,  # the parameter to compare with the others. 
    x='total_bill', #value in x_axis
    y='tip',        #Value in y_axis
    hue='sex',     #bring difered colours to each sex: female, male
    col='day',     #Compare diferent days. 
    kind='scatter', # define the tipe of data unit: plot
    col_wrap=2). # number of columns per graph

# %% [markdown]
# # Seaborn resources:
# - Datacamp has a seaborn cheatsheet that covers the basics: https://
# images.datacamp.com/image/upload/v1676302629/Marketing/Blog/Seaborn_Cheat_Sheet.pdf
# - Or look at the seaborn gallery: http://seaborn.pydata.org/examples/index.html

# %% [markdown]
# # Ploty

# %%
import plotly.graph_objects as go

x1= np.array (['Luffy', 'zoro', 'Nami', 'Usoopp', 'Sanji'])
y1 = np.array([110, 180, 240, 99, 220])

# %% [markdown]
# # plotly syntax is different from matplotlib/seaborn
# 1. make the figure
# 2. Choose the plot type and the data
# 3. Update layout to include titles
# 4. show the plot
#
# This is kind of interactive plot.

# %%
graph = go.Figure()
graph.add_trace(go.Bar(x=x1, y=y1))

graph.update_layout(
    title='Pirate Scores',
    xaxis_title='Pirates',
    yaxis_title='Score'
)

graph.show()

# %%
graph = go.Figure()
graph.add_trace(go.Scatter(
    x=x1, 
    y=y1,
    mode= 'markers',
    marker = dict(size=15,
                  color='hotpink',
                  opacity=1,
                  line= dict(width = 5, color='purple'))))

graph.update_layout(title = 'Interactive Pirates Plot',
    xaxis_title='Pirates',
    yaxis_title='Score',
    width=500,
    height= 500
)

graph.show()

# %% [markdown]
# size=15, # point size
# color='hotpink', # point colour
# opacity=1, # point transparency/alpha
# line=dict(width=5, color='purple') # point outline

# %% [markdown]
# # Making wordclouds

# %%
import sys
# !{sys.executable} -m pip install wordcloud

# %%
from wordcloud import WordCloud
df = pd.read_csv('https://raw.githubusercontent.com/prasertcbs/basic-dataset/master/movie_quotes.csv',
                on_bad_lines='skip')
df
# Out:
#                                                  quote  \
# 0                      Do, or do not. There is no try.
# 1    Listen to them. Children of the night. What mu...
# 2                              It's alive! It's alive!
# 3    Oh, no, it wasn't the airplanes. It was Beauty...
# 4    Magic Mirror on the wall, who is the fairest o...
# ..                                                 ...
# 727  I didn't know if you were lost. Stick with me....
# 728  This guy's awesome! He's holding his own while...
# 729     Murder is murder, it don’t matter who you are.
# 730  You know what a lion is? A lion is a strong an...
# 731  That was the best acting i've ever seen in my ...
#
#                                               movie   type  year
# 0    Star Wars: Episode V - The Empire Strikes Back  movie  1890
# 1                                           Dracula  movie  1931
# 2                                      Frankenstein  movie  1931
# ...

# %%
text = ''.join(each for each in df.quote)

wordcloud = WordCloud(background_color= 'white',
                      colormap= 'inferno',
                      random_state = 613). generate(text)

fig, ax= plt.subplots(figsize=(7,3))
ax.imshow(wordcloud, interpolation='bilinear')
ax.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# # ben diagrams

# %%
# !pip install matplotlib-venn

from matplotlib_venn import venn2, venn2_circles, venn2_unweighted
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for matplotlib-venn: filename=matplotlib_venn-1.1.2-py3-none-any.whl size=45388 sha256=f7011fe55cff72541f6a5b8d3399b254007908496e2cf835e028a8b7c6989a82
#   Stored in directory: /Users/marylopez/Library/Caches/pip/wheels/86/29/d8/0f3c5a37c967a34fb40aaabd414f92104d2ad5fb149c0114a1
# Successfully built matplotlib-venn
# ...

# %%
A = set(['apple', 'banana', 'watermelon'])
B = set(['pumpkin', 'blueberry', 'apple', 'key lime'])

diagram = venn2_unweighted([A, B],
                        set_labels = ('Fruits', 'Pies'),
                        set_colors=('blue', 'red'),
                        alpha=0.5)
plt.show()

# %%
A = set(['apple', 'banana', 'watermelon'])
B = set(['pumpkin', 'blueberry', 'apple', 'key lime'])
diagram = venn2_unweighted([A, B],
                        set_labels = ('Fruits', 'Pies'),
                        set_colors=('blue', 'red'),
                        alpha=0.5)

diagram.get_label_by_id("10").set_text('\n'.join(A - B)) #left
diagram.get_label_by_id("11").set_text('\n'.join(A & B)) #middle slice
diagram.get_label_by_id("01").set_text('\n'.join(B - A)) #right
